# %%
import logging
import time
from datetime import datetime as dt
import pandas as pd
import requests
import json
from sqlalchemy import create_engine, text, types
from sqlalchemy.exc import OperationalError, InterfaceError, DatabaseError
from dotenv import dotenv_values
## Setting up Key elements of a request
##URL

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

##This section is to fetch the variables into context
config= dotenv_values()
# align the key label with your .env file !
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_user = config['POSTGRES_USER']
pg_password = config['POSTGRES_PASS']

base_api_url = config['WB_BASE_API_URL']



###Declare/Initialize Variables
start_year='1988'
end_year='2012'

country_codes=['DE'
               ,'IN' 
               ,'US'
               ,'AF'
               ]

indicator_codes=[
                'IT.NET.BBND.P2'
                ,'IT.NET.SECR.P6'
                ,'SL.UEM.TOTL.ZS'
                ,'SI.POV.NAHC'
                ,'SE.ADT.LITR.ZS'
                ,'IT.NET.USER.P2'
                ,'SE.TER.ENRR'
                ,'SE.SEC.ENRR'
                ,'IE.ICT.TOTL.GD.ZS'
                ,'IT.TEL.INVS.RV.ZS'
                ,'NY.GDP.PCAP.KD.ZG'
                ,'IT.NET.BNDW.PC'
                ,'IT.CEL.SETS.P2'
                ,'IT.MLT.MAIN.P2'
                ]   

format_type="json"
per_page=100
page=1

col_type_dict = {
                 'extracted_at':types.DateTime() 
                 ,'country_code':types.String() 
                 ,'indicator_code':types.String() 
                 ,'extracted_data':types.JSON()
                }                    

col_data_dict = {
                'extracted_at':[] 
                ,'country_code':[]
                ,'indicator_code':[] 
                ,'extracted_data':[]
               }

# Create the database connection string
DATABASE_URL = f"postgresql://{pg_user}:{pg_password}@{pg_host}:{pg_port}/{pg_db}"
# Use pandas to import the DataFrame to the PostgreSQL table
table_name = f"api_data_digi_sa_work"

###Defining functions
class apiOperations:
    def generate_monthly_dates(self, start_date, end_date):
        logging.info(f"Generating monthly dates between Start Date: {start_date} and End Date: {end_date}")
        first_days = pd.date_range(start=start_date, end=end_date, freq='MS')
        monthly_dates = [(first_day.strftime('%Y-%m-%d'), (first_day + pd.offsets.MonthEnd(0)).strftime('%Y-%m-%d')) for first_day in first_days]
        return monthly_dates

    def api_call(self, base_api_url, query_dict, query_params):
        logging.info(f"API call made to {base_api_url} with Query: {query_dict}")
        BASE_URL = f"{base_api_url}/country/{country}/indicator/{indicator}?date={start_year}:{end_year}"
        API_URL= BASE_URL.format(**query_dict)
        try:
            start_time = time.time()
            response_obj = requests.get(API_URL, params=query_params)
            response_obj.raise_for_status()
            end_time = time.time()
            logging.info(f"API call duration: {end_time - start_time:.2f} seconds")
            if response_obj.status_code == 200 and response_obj.text.strip():
                logging.info(f"Response after API call {response_obj.text}")
                return response_obj.text
            else:
                logging.warning(f"Request failed with status code {response_obj.status_code} or empty response")
                return None
        except requests.exceptions.RequestException as e:
            logging.error(f"API call failed for {query_dict}: {e}")
            return None

    
    def prepare_columns_data(self, query_dict, response_str):
        logging.info(f"Creating response for station {query_dict['country']}")
        col_data_dict['extracted_at'].append(dt.now().strftime('%Y-%m-%d %H:%M:%S'))
        col_data_dict['country_code'].append(country)
        col_data_dict['indicator_code'].append(query_dict["indicator"])
        col_data_dict['extracted_data'].append(json.loads(response_str))   

    def perform_db_ops(self, DATABASE_URL, col_type_dict, col_data_dict):
        logging.info(f"Writing data to DB")
        database_df = pd.DataFrame(col_data_dict)
        try:
            start_time = time.time()
            engine = create_engine(DATABASE_URL, connect_args={"connect_timeout": 5})
            database_df.to_sql(table_name, engine, schema=pg_schema, if_exists='replace', index=False, dtype=col_type_dict)
            end_time = time.time()
            logging.info(f"DB write duration: {end_time - start_time:.2f} seconds")
            logging.info("Data successfully imported to the PostgreSQL database.")
            with engine.connect() as connection:
                result = connection.execute(text(f"SELECT count(*) FROM {pg_schema}.{table_name};"))
                logging.info(f"Count of Rows in table {table_name}: {result.scalar()}")
        except (OperationalError, InterfaceError, DatabaseError) as db_err:
            logging.error(f"Database error occurred: {db_err}")
        except Exception as e:
            logging.error(f"An unexpected error occurred: {e}")

# Creating an instance of the class
api_ops = apiOperations()

# Control the flow of code
total_start_time = time.time()
for country in country_codes:
    for indicator in indicator_codes:       
        query_dict={
                    'country': country
                    ,'indicator': indicator
                    ,'start_date': start_year
                    ,'end_date': end_year
                    }     
        query_params={  
                    'format': format_type
                    ,'per_page': per_page
                    ,'page': page
                    }   
        response_str = api_ops.api_call(base_api_url, query_dict, query_params)
        
        if response_str:
            api_ops.prepare_columns_data(query_dict, response_str)

# Perform DB operations once after collecting all data
api_ops.perform_db_ops(DATABASE_URL, col_type_dict, col_data_dict)
total_end_time = time.time()
logging.info(f"Total execution time: {total_end_time - total_start_time:.2f} seconds")
# Out:
# 2024-10-27 16:18:25,575 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'IT.NET.BBND.P2', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:25,736 - INFO - API call duration: 0.16 seconds
# 2024-10-27 16:18:25,736 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2012","value":34.5501,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2011","value":33.7099,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2010","value":32.3663,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2009","value":30.8451,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2008","value":27.9989,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2007","value":24.2949,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2006","value":18.3315,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2005","value":13.1471,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2004","value":8.52694,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2003","value":5.44381,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2002","value":3.90528,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2001","value":2.56304,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2000","value":0.323972,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1999","value":null,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1998","value":null,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1997","value":null,"unit":"","obs_status":"","decimal":2},{"indicator":{"id":"IT.NET.BBND.P2","value":"Fixed broadband subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1996","value":null,"unit":"","obs_status":"","decimal":2},{"in ...
# 2024-10-27 16:18:25,738 - INFO - Creating response for station DE
# 2024-10-27 16:18:25,739 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'IT.NET.SECR.P6', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:25,906 - INFO - API call duration: 0.17 seconds
# 2024-10-27 16:18:25,910 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2012","value":2194.9044898179,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2011","value":1471.90314571602,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2010","value":1049.31794333683,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2009","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2008","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2007","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2006","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2005","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2004","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2003","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2002","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2001","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2000","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1999","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1998","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1997","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.NET.SECR.P6","value":"Secure Internet servers (per 1 million people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1996","value":null,"unit":"","obs_status":"","decimal":0},{"indicat ...
# 2024-10-27 16:18:25,915 - INFO - Creating response for station DE
# 2024-10-27 16:18:25,922 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'SL.UEM.TOTL.ZS', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:26,166 - INFO - API call duration: 0.24 seconds
# 2024-10-27 16:18:26,166 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2012","value":5.379,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2011","value":5.825,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2010","value":6.967,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2009","value":7.742,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2008","value":7.525,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2007","value":8.658,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2006","value":10.25,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2005","value":11.167,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2004","value":10.727,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2003","value":9.779,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2002","value":8.482,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2001","value":7.773,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2000","value":7.917,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1999","value":8.854,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1998","value":9.787,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SL.UEM.TOTL.ZS","value":"Unemployment, total (% of total labor force) (modeled ILO estimate)"},"country":{"id":"DE","value":"Germany"},"coun ...
# 2024-10-27 16:18:26,168 - INFO - Creating response for station DE
# 2024-10-27 16:18:26,168 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'SI.POV.NAHC', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:26,326 - INFO - API call duration: 0.16 seconds
# 2024-10-27 16:18:26,328 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2012","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2011","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2010","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2009","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2008","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2007","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2006","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2005","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2004","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2003","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2002","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2001","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2000","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1999","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1998","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"SI.POV.NAHC","value":"Poverty headcount ratio at national poverty lines (% of population)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1997","value":null,"unit":"","obs_stat ...
# 2024-10-27 16:18:26,330 - INFO - Creating response for station DE
# 2024-10-27 16:18:26,333 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'SE.ADT.LITR.ZS', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:26,513 - INFO - API call duration: 0.18 seconds
# 2024-10-27 16:18:26,515 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2012","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2011","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2010","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2009","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2008","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2007","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2006","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2005","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2004","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2003","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2002","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2001","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2000","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1999","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1998","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% of people ages 15 and above)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1997","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.ADT.LITR.ZS","value":"Literacy rate, adult total (% o ...
# 2024-10-27 16:18:26,517 - INFO - Creating response for station DE
# 2024-10-27 16:18:26,519 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'IT.NET.USER.P2', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:26,687 - INFO - API call duration: 0.17 seconds
# 2024-10-27 16:18:26,688 - INFO - Response after API call [{"message":[{"id":"175","key":"Invalid format","value":"The indicator was not found. It may have been deleted or archived."}]}]
# 2024-10-27 16:18:26,690 - INFO - Creating response for station DE
# 2024-10-27 16:18:26,692 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'SE.TER.ENRR', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:26,855 - INFO - API call duration: 0.16 seconds
# 2024-10-27 16:18:26,855 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2012","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2011","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2010","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2009","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2008","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2007","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2006","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2005","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2004","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2003","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2002","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2001","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2000","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1999","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1998","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1997","value":48.954719543457,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1996","value":48.2839698791504,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.TER.ENRR","value":"School enrollment, tertiary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1995","value":46.4355697631836,"unit":"","obs_status":"","decimal":0},{ ...
# 2024-10-27 16:18:26,858 - INFO - Creating response for station DE
# 2024-10-27 16:18:26,859 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'SE.SEC.ENRR', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:27,020 - INFO - API call duration: 0.16 seconds
# 2024-10-27 16:18:27,021 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2012","value":104.442237854004,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2011","value":105.34651184082,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2010","value":104.891357421875,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2009","value":103.314292907715,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2008","value":103.240730285645,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2007","value":102.009773254395,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2006","value":102.486396789551,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2005","value":101.436492919922,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2004","value":101.377777099609,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2003","value":101.226783752441,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2002","value":100.853607177734,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2001","value":99.554801940918,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2000","value":99.1294326782227,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1999","value":99.5309066772461,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1998","value":99.2678070068359,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1997","value":104.170478820801,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR","value":"School enrollment, secondary (% gross)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1996","value":103.8291015625,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SE.SEC.ENRR ...
# 2024-10-27 16:18:27,022 - INFO - Creating response for station DE
# 2024-10-27 16:18:27,025 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'IE.ICT.TOTL.GD.ZS', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:27,180 - INFO - API call duration: 0.15 seconds
# 2024-10-27 16:18:27,182 - INFO - Response after API call [{"page":0,"pages":0,"per_page":0,"total":0,"sourceid":null,"lastupdated":null},null]
# 2024-10-27 16:18:27,185 - INFO - Creating response for station DE
# 2024-10-27 16:18:27,186 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'IT.TEL.INVS.RV.ZS', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:27,355 - INFO - API call duration: 0.17 seconds
# 2024-10-27 16:18:27,356 - INFO - Response after API call [{"page":0,"pages":0,"per_page":0,"total":0,"sourceid":null,"lastupdated":null},null]
# 2024-10-27 16:18:27,358 - INFO - Creating response for station DE
# 2024-10-27 16:18:27,359 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'NY.GDP.PCAP.KD.ZG', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:27,549 - INFO - API call duration: 0.19 seconds
# 2024-10-27 16:18:27,550 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2012","value":0.230160992711959,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2011","value":5.86963573749217,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2010","value":4.33960677706354,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2009","value":-5.45457716940945,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2008","value":1.1520297421751,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2007","value":3.11424588261349,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2006","value":3.9336103307084,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2005","value":0.788917115869921,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2004","value":1.1970553521185,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2003","value":-0.755077166602604,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2002","value":-0.365628327264105,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2001","value":1.5105582606794,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2000","value":2.77322125091402,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1999","value":1.82142803058096,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1998","value":1.99848532107309,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1997","value":1.6433342731292,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1996","value":0.514437284599765,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.G ...
# 2024-10-27 16:18:27,552 - INFO - Creating response for station DE
# 2024-10-27 16:18:27,552 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'IT.NET.BNDW.PC', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:27,712 - INFO - API call duration: 0.16 seconds
# 2024-10-27 16:18:27,713 - INFO - Response after API call [{"page":0,"pages":0,"per_page":0,"total":0,"sourceid":null,"lastupdated":null},null]
# 2024-10-27 16:18:27,715 - INFO - Creating response for station DE
# 2024-10-27 16:18:27,716 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'IT.CEL.SETS.P2', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:27,906 - INFO - API call duration: 0.19 seconds
# 2024-10-27 16:18:27,907 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2012","value":113.3108833,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2011","value":111.6386991,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2010","value":108.6995416,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2009","value":129.2138879,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2008","value":129.9265409,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2007","value":118.5370597,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2006","value":105.5115846,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2005","value":97.6097572,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2004","value":87.76291359,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2003","value":79.65893192,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2002","value":72.60008929,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2001","value":68.85395013,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2000","value":59.10608068,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1999","value":28.74800454,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1998","value":17.06605986,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1997","value":10.1625708,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU", ...
# 2024-10-27 16:18:27,908 - INFO - Creating response for station DE
# 2024-10-27 16:18:27,909 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'DE', 'indicator': 'IT.MLT.MAIN.P2', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:28,074 - INFO - API call duration: 0.16 seconds
# 2024-10-27 16:18:28,075 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2012","value":61.9,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2011","value":63.6,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2010","value":65.4,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2009","value":66.3,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2008","value":62,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2007","value":65.3,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2006","value":66.6,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2005","value":66.8,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2004","value":66.4,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2003","value":66,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2002","value":65.4,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2001","value":63.9,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"2000","value":61.4,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1999","value":59,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1998","value":56.7,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1997","value":54.9,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"DE","value":"Germany"},"countryiso3code":"DEU","date":"1996","value":53.6,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed ...
# 2024-10-27 16:18:28,077 - INFO - Creating response for station DE
# 2024-10-27 16:18:28,079 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'IN', 'indicator': 'IT.NET.BBND.P2', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:28,237 - INFO - API call duration: 0.16 seconds
# ...
# 2024-10-27 16:18:34,864 - INFO - Creating response for station AF
# 2024-10-27 16:18:34,865 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'AF', 'indicator': 'IE.ICT.TOTL.GD.ZS', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:35,029 - INFO - API call duration: 0.16 seconds
# 2024-10-27 16:18:35,032 - INFO - Response after API call [{"page":0,"pages":0,"per_page":0,"total":0,"sourceid":null,"lastupdated":null},null]
# 2024-10-27 16:18:35,035 - INFO - Creating response for station AF
# 2024-10-27 16:18:35,038 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'AF', 'indicator': 'IT.TEL.INVS.RV.ZS', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:35,203 - INFO - API call duration: 0.16 seconds
# 2024-10-27 16:18:35,204 - INFO - Response after API call [{"page":0,"pages":0,"per_page":0,"total":0,"sourceid":null,"lastupdated":null},null]
# 2024-10-27 16:18:35,207 - INFO - Creating response for station AF
# 2024-10-27 16:18:35,209 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'AF', 'indicator': 'NY.GDP.PCAP.KD.ZG', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:35,371 - INFO - API call duration: 0.16 seconds
# 2024-10-27 16:18:35,374 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2012","value":8.24714425590732,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2011","value":-3.21136430314944,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2010","value":11.099219918376,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2009","value":17.1435343247272,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2008","value":1.86475446412054,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2007","value":11.8033826639966,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2006","value":1.0849881970577,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2005","value":7.32187384466143,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2004","value":-2.49725462645728,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2003","value":0.927029119446615,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2002","value":20.5679634606166,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2001","value":-10.1019664254902,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2000","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1999","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1998","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1997","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id":"NY.GDP.PCAP.KD.ZG","value":"GDP per capita growth (annual %)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1996","value":null,"unit":"","obs_status":"","decimal":1},{"indicator":{"id ...
# 2024-10-27 16:18:35,381 - INFO - Creating response for station AF
# 2024-10-27 16:18:35,386 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'AF', 'indicator': 'IT.NET.BNDW.PC', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:35,598 - INFO - API call duration: 0.21 seconds
# 2024-10-27 16:18:35,600 - INFO - Response after API call [{"page":0,"pages":0,"per_page":0,"total":0,"sourceid":null,"lastupdated":null},null]
# 2024-10-27 16:18:35,603 - INFO - Creating response for station AF
# 2024-10-27 16:18:35,604 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'AF', 'indicator': 'IT.CEL.SETS.P2', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:35,831 - INFO - API call duration: 0.22 seconds
# 2024-10-27 16:18:35,833 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2012","value":50.35079702,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2011","value":47.17359546,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2010","value":36.23965543,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2009","value":38.34172829,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2008","value":29.88931593,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2007","value":18.02123984,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2006","value":9.905952707,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2005","value":4.915778177,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2004","value":2.547386592,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2003","value":0.883192104,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2002","value":0.119046168,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2001","value":0,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2000","value":0,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1999","value":0,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1998","value":0,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1997","value":0,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.CEL.SETS.P2","value":"Mobile cellular subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"cou ...
# 2024-10-27 16:18:35,835 - INFO - Creating response for station AF
# 2024-10-27 16:18:35,839 - INFO - API call made to https://api.worldbank.org/v2 with Query: {'country': 'AF', 'indicator': 'IT.MLT.MAIN.P2', 'start_date': '1988', 'end_date': '2012'}
# 2024-10-27 16:18:36,008 - INFO - API call duration: 0.17 seconds
# 2024-10-27 16:18:36,009 - INFO - Response after API call [{"page":1,"pages":1,"per_page":100,"total":25,"sourceid":"2","lastupdated":"2024-10-24"},[{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2012","value":0.295,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2011","value":0.046,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2010","value":0.0588,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2009","value":0.0187,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2008","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2007","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2006","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2005","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2004","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2003","value":0.161,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2002","value":0.155,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2001","value":0.143,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"2000","value":0.144,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1999","value":0.146,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1998","value":0.151,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1997","value":0.157,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"IT.MLT.MAIN.P2","value":"Fixed telephone subscriptions (per 100 people)"},"country":{"id":"AF","value":"Afghanistan"},"countryiso3code":"AFG","date":"1996","value":0.163," ...
# 2024-10-27 16:18:36,012 - INFO - Creating response for station AF
# 2024-10-27 16:18:36,015 - INFO - Writing data to DB
# 2024-10-27 16:18:36,609 - INFO - DB write duration: 0.59 seconds
# 2024-10-27 16:18:36,610 - INFO - Data successfully imported to the PostgreSQL database.
# 2024-10-27 16:18:36,634 - INFO - Count of Rows in table api_data_digi_sa_work: 56
# 2024-10-27 16:18:36,646 - INFO - Total execution time: 11.07 seconds
